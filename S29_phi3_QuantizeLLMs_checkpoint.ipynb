# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab_Notebooks/Session29
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab_Notebooks/Session29

# %%
# !!git clone https://github.com/ggerganov/llama.cpp
# Out:
# ["Cloning into 'llama.cpp'...",
#  'remote: Enumerating objects: 33360, done.\x1b[K',
#  'remote: Counting objects:   0% (1/9049)\x1b[K',
#  'remote: Counting objects:   1% (91/9049)\x1b[K',
#  'remote: Counting objects:   2% (181/9049)\x1b[K',
#  'remote: Counting objects:   3% (272/9049)\x1b[K',
#  'remote: Counting objects:   4% (362/9049)\x1b[K',
#  'remote: Counting objects:   5% (453/9049)\x1b[K',
#  'remote: Counting objects:   6% (543/9049)\x1b[K',
#  'remote: Counting objects:   7% (634/9049)\x1b[K',
#  'remote: Counting objects:   8% (724/9049)\x1b[K',
#  'remote: Counting objects:   9% (815/9049)\x1b[K',
#  'remote: Counting objects:  10% (905/9049)\x1b[K',
#  'remote: Counting objects:  11% (996/9049)\x1b[K',
#  'remote: Counting objects:  12% (1086/9049)\x1b[K',
#  'remote: Counting objects:  13% (1177/9049)\x1b[K',
#  'remote: Counting objects:  14% (1267/9049)\x1b[K',
#  'remote: Counting objects:  15% (1358/9049)\x1b[K',
# ...

# %%
# !cd llama.cpp && GGML_CUDA=1 make && pip install -r requirements.txt
# Out:
# I ccache not found. Consider installing it for faster compilation.
# I llama.cpp build info:
# I UNAME_S:   Linux
# I UNAME_P:   x86_64
# I UNAME_M:   x86_64
# I CFLAGS:    -Iggml/include -Iggml/src -Iinclude -Isrc -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_OPENMP -DGGML_USE_LLAMAFILE -DGGML_USE_CUDA -I/usr/local/cuda/include -I/usr/local/cuda/targets/x86_64-linux/include -DGGML_CUDA_USE_GRAPHS  -std=c11   -fPIC -O3 -g -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -fopenmp -Wdouble-promotion
# ...

# %%
from huggingface_hub import snapshot_download

# %%
model_name = "Shivdutta/phi3-merged"

# %%
methods = ["q4_k_m", "q5_k_m"]

# %%
base_model = "./orignal_model/"

# %%
quantized_path = "./quantized_model/"

# %%
snapshot_download(repo_id=model_name, local_dir=base_model, local_dir_use_symlinks=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1212: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
# ...

# %%
orignal_model = quantized_path+"/fp16.gguf"

# %%
# !mkdir ./quantized_model/

# %%
# !python llama.cpp/convert_hf_to_gguf.py ./orignal_model/ --outtype f16 --outfile ./quantized_model/FP16.gguf
# Out:
# INFO:hf-to-gguf:Loading model: orignal_model
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00002.safetensors'
# INFO:hf-to-gguf:token_embd.weight,         torch.bfloat16 --> F16, shape = {3072, 32064}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,    torch.bfloat16 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,     torch.bfloat16 --> F16, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,       torch.bfloat16 --> F16, shape = {3072, 16384}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,     torch.bfloat16 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.0.attn_output.weight,  torch.bfloat16 --> F16, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.0.attn_qkv.weight,     torch.bfloat16 --> F16, shape = {3072, 9216}
# ...

# %%
import os

# %%
for m in methods:
  qtype = f"{quantized_path}/{m.upper()}.gguf"
  os.system("./llama.cpp/llama-quantize "+quantized_path+"FP16.gguf "+qtype+" "+m)

# %%
# !./llama.cpp/llama-cli -m ./quantized_model/Q4_K_M.gguf -n 90 --repeat_penalty 1.0 --color -i -r "User: " -f llama.cpp/prompts/chat-with-bob.txt
# Out:
# Log start
# main: build = 3669 (4db04784)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1725572969
# llama_model_loader: loaded meta data with 33 key-value pairs and 197 tensors from ./quantized_model/Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = phi3
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Phi 3.5 Mini Instruct
# llama_model_loader: - kv   3:                       general.organization str              = Microsoft
# llama_model_loader: - kv   4:                           general.finetune str              = Instruct
# ...

# %%
# !./llama.cpp/llama-cli -m ./quantized_model/Q5_K_M.gguf -n 90 --repeat_penalty 1.0 --color -i -r "User: " -f llama.cpp/prompts/chat-with-bob.txt
# Out:
# Log start
# main: build = 3669 (4db04784)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1725572996
# llama_model_loader: loaded meta data with 33 key-value pairs and 197 tensors from ./quantized_model/Q5_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = phi3
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Phi 3.5 Mini Instruct
# llama_model_loader: - kv   3:                       general.organization str              = Microsoft
# llama_model_loader: - kv   4:                           general.finetune str              = Instruct
# ...

# %%
from huggingface_hub import HfApi, HfFolder, upload_file

# %%
from google.colab import userdata
huggingface = userdata.get('huggingface')
api = HfApi(token=huggingface)

# %%
model_path = "./quantized_model/Q4_K_M.gguf"
repo_name = "S29-phi3-merged-0.2_GGUF"
repo_url = api.create_repo(repo_name, private=False)

# %%
api.upload_file(
    path_or_fileobj=model_path,
    path_in_repo="Q4_K_M.gguf",
    repo_id= "Shivdutta/S29-phi3-merged-0.2_GGUF",
    repo_type="model",
)
# Out:
# Q4_K_M.gguf:   0%|          | 0.00/2.39G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Shivdutta/S29-phi3-merged-0.2_GGUF/commit/f19ed67cbbf3681ad55c80ff05ca7ca025a15119', commit_message='Upload Q4_K_M.gguf with huggingface_hub', commit_description='', oid='f19ed67cbbf3681ad55c80ff05ca7ca025a15119', pr_url=None, pr_revision=None, pr_num=None)

# %%
model_path = "./quantized_model/Q5_K_M.gguf"
repo_name = "S29-phi3-merged-0.3_GGUF"
repo_url = api.create_repo(repo_name, private=False)

# %%
api.upload_file(
    path_or_fileobj=model_path,
    path_in_repo="Q5_K_M.gguf",
    repo_id= "Shivdutta/S29-phi3-merged-0.3_GGUF",
    repo_type="model",
)
# Out:
# Q5_K_M.gguf:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Shivdutta/S29-phi3-merged-0.3_GGUF/commit/fca3c3bed9535ee4fc9554c504d1bc2b1f5a38e2', commit_message='Upload Q5_K_M.gguf with huggingface_hub', commit_description='', oid='fca3c3bed9535ee4fc9554c504d1bc2b1f5a38e2', pr_url=None, pr_revision=None, pr_num=None)
